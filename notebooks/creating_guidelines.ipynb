# %%
from utils import *

config = load_config()
notes = config.representative_notes
# Out:
# /home/wjang/2024_chatbot_noteaid/data/raw/representative_notes_50_new.xlsx

# %%
text = notes.loc[49,"text"]
print(text)
# Out:
#
# Name:  ___.                 Unit No:   ___
#
# Admission Date:  ___              Discharge Date:   ___
#
# Date of Birth:  ___             Sex:   M
#
# Service: MEDICINE
#
# Allergies:
# Erythromycin Base
#
# Attending: ___
#
# Chief Complaint:
# Acute renal failure
#
# Major Surgical or Invasive Procedure:
# None
#
# History of Present Illness:
# This is a ___ y/o M with h/o CAD, HLD, CHF (EF 35-40%) and
# dementia presenting to ___ from ___ (___
# ___) with lethary and hypotension.
# .
# Per report from ___, patient had been lethargic x 1 week after
# starting trial dose of zoloft. Medication was subsequently
# stopped however patient remain lethargic and had difficulty
# ambulating, requiring a wheelchair (normally patient able to
# ambulate with walker). Today, patient found to be increasing
# lethargic with a BP of 76/doppler (normally runs 90-100/60).
# Patient was then brought to ED for further evaluation.
# .
# ...
